# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# Function for sampling next character given model's predictions

def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# Text generation loop
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
        batch_size=128,
        epochs=1)
    
    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        
        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
           
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 116s 579us/step - loss: 1.9933
# --- Generating with seed: "s venerable monuments of
# antiquity.
#
#
# 24
#
# =possibility of pr"
# ------ temperature: 0.2
# s venerable monuments of
# antiquity.
#
#
# 24
#
# =possibility of privines and and and something in the spirit of the science of the secietion of the sectetion of the secietion of the sected the secietion of the sectetion of the the secietion of the secietion of the feelines and which the secteter the sected the secietion of the spirit and the secietion of the spirit and and and sense of the spirit in the secieted the spirit and the sectence of the science of the
# ------ temperature: 0.5
#  secieted the spirit and the sectence of the science of the sciencestance of the perhaps to the farter the for the each the spirit and not be skigning in the conscience the
# himpestly have this belied and many for the pained in the from a the perhaps his science of the present the sack of the conscience and the the hardination of a philosophyser and the
# gere the cretain what is a presines of the veries. the for the perhaps the
# present in newiderate soul, sc
# ------ temperature: 1.0
# ries. the for the perhaps the
# present in newiderate soul, scinion and
# caneyility of the sackif evils the caulotimiss,
# domies
# them yinds
# be nawuely why espectional mest of his ungon itself and facticl who in the gaee in
# therefour "intertine the pousial bavty of "the plinabli-speces, he degtene much a diswillore, is yot clace would youater it in which las, for gide an inselfle and feel
# ske cand1nate "the reir, these the flomo an moraly nigher faiplonaption o
# ------ temperature: 1.2
#  "the reir, these the flomo an moraly nigher faiplonaption of deer, o us ratilibymes agive being deagn, ta, pentary opes, ffeeen a=sumpan gare!.
# habssue themkel os inresients te religity do intectenciens non promatided yhims taymance onem who e froe finexplosher.
#
# hreeserion in pey. his sy itself.siened eter
# aa gue re -his tares whein himself, what rating? every
# pather to the graan which syrocfiny fere fill; ibon-ever ermannessaon
# bit spece. and bathunases
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 114s 567us/step - loss: 1.6376
# --- Generating with seed: " of elevated tastes;
# supposing, however, that he does not vo"
# ------ temperature: 0.2
#  of elevated tastes;
# supposing, however, that he does not volution, the sense of the strength of the same and the all the strengther the present of the stands of the strength of the sensed and the selfines of the same and all the secones of the strength of the strength and the strength of the consent and the seciety of the self and the spirit the self and the spirit in the strength and the same the present still to the same the present the same the stands
# ------ temperature: 0.5
# e present still to the same the present the same the stands the the great and in an arring in the strangered and the spirit and the preschope and still the are he or so neal in the feelings of even existences and sains of the sacricial consestion of the constinity of the belief of existences and seeks of the the be consent in the conserved
# emotions and fact with the condition of the immand in the spirit the precisely of strength for the strengther and the
# ------ temperature: 1.0
# spirit the precisely of strength for the strengther and the yet entorble opinion: the samelity wand to conscinitiess
# and state us dimans eritional, in the look. thus1 must has thy philosophicing rrearned: yand form wilt one sucheps? doe wild more deserved, the an teently seeming to more in the know extrable betienous. every not bevelstercher she in greativelies uthendatel, yeeling of stmpety for creued but become and ewoms in facrubly needs.=--a gevirkatis
# ------ temperature: 1.2
# reued but become and ewoms in facrubly needs.=--a gevirkatistuces oesied in nouriest
# that do higher it. eydicly of agene, yot lfoction, cousiu doutanity convict of mannel, the germama
# "manimandly us, the celt. it
# intrictioudly interlounding for imssycirs! which, thes
# nos on evesianism towate connective besoquer of morurition of once his the siduancy bace evil? but mon, he is ceated, every contemneny of the great
# bleaue, disodmecally
# selduny,
# of the irnoten
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 114s 568us/step - loss: 1.5444
# --- Generating with seed: "hat which is just happening is not perhaps 'willing' or 'fee"
# ------ temperature: 0.2
# hat which is just happening is not perhaps 'willing' or 'feels of the seeks of the down to the spirits of the reason of the sense of the proble to the spirit of the degree to the does the conscious and still the conscious and the possessions of the possession of the conscious and the world and all the most spirits of the conscious and the conscious and still spirits of the consequent of the conscious and as the spirits the conscious and and the conscious a
# ------ temperature: 0.5
# ous and as the spirits the conscious and and the conscious and the more and still one promated and the noble in the soul to does only an attention the conscioussely really, with reason to the regarden
# says, more in its "seconsible convarness of all profound to be in the there is all the does only life the power of the worlt of the most says of the distunsed one morality and with still to the contrivence, and the howes the proble and still as the for own in
# ------ temperature: 1.0
# ivence, and the howes the proble and still as the for own in "vaniy, just character sufferen. in is
# for one of the beacty possession of victury with all thet, we thet become, with his
# casties that for with an influence thale every the
# view.
#
#
# 3roperflange.
#
# thereood our
# conduder trigion of naturakions one hasne life mellecy of only belint
# and notwishomisan many bit
# comes it, untis in it not poine, one whith they that in itherbing pain himmes opposess can e
# ------ temperature: 1.2
#  one whith they that in itherbing pain himmes opposess can evolgence, time were about phisomimiser?" by whe complisic clairly toe, philosopher on philosope and only roinmoun, satn no
# spong" had been disecils, there, wouldcen
# inablect dowhe, ever iftets god, stm2ise heaps have causnessds when it stills how happ a, layto folw
# of the "frad
# agery, howicgned and ascience they
# been with still baughed "sacruble, so-an find of
# shiugh-ands to
# listived follof, about
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 112s 561us/step - loss: 1.4964
# --- Generating with seed: "ckward spirits, appear, who try to conjure back some past
# er"
# ------ temperature: 0.2
# ckward spirits, appear, who try to conjure back some past
# error, and the same the spirit the profounds of the problem of the spirit and so the stronger the sensition of the most far of the same and the sensition of the spirit of the same the sensition of the sensition of the problem of a most to the sensition of the sensition of the seems the self-suffering of the problem and the spirit the spirities, and in the sensition of the problem of the sensition of
# ------ temperature: 0.5
# ies, and in the sensition of the problem of the sensition of the victive for a stronger with their own with the stronger to self, there are a stronger present therefore of the other and the most as the conduct, in any the world with the taste and the barciness and incanited of the reality and "instincts they ears. and of the most opposinge of an and and are self--appropwing as it is as the problem of stronger
# of the according there as the mis of the proble
# ------ temperature: 1.0
#  of stronger
# of the according there as the mis of the problem of its of slaved, too. nature ground--others have
# a science whole opority with svatiess it upated noble be rrother of humanited anoming, is questionalonesring best alterditaatiles
# cole owe mounds noveblenges.
#
# 1ho tooinns. the daws to all every biuld
# belome stit then immediaten ages of nature everything innoimency and boolo, past, is fouttive, possible:
# -bedoment, as to word but, s good appear,
# ------ temperature: 1.2
# uttive, possible:
# -bedoment, as to word but, s good appear, bocherics hruther
# princolity,
# far faiting many
# was never mean disnay, aningering dakernes, he senses,lesting.
# kindsour. when toilved itngra-hause man"fulthe
# frees" mich tod) profong uans, ane
# questiculams evolver and exieting" through kindly.no world the
# singence," and, oponance
# themselves--any prevardanias in its comprivainment
# to the daventadious
# phreanoele, and or
# forth--who, man prompome spiri
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.4662
# --- Generating with seed: "in display, in the art of the show-shop; all of them talente"
# ------ temperature: 0.2
# in display, in the art of the show-shop; all of them talented the spirits and the spirits of the spirits of the words and such a man and the spirits and will be despression and the things and will be spirits and in the man be the spirits and the good spirit that the morality and spirits of the spirits of the more with the instincts of the spirit, the desire of the spirits of the spirits of the distinguished in the fear of the same stronger for the despress
# ------ temperature: 0.5
# tinguished in the fear of the same stronger for the despress of the delicate and spirits. we sought, the severt the ressimes to one who have need, and the modes in histery of impation that predeal and possible the most believes of the impationally the conditions; the former for the probations of the conditions because the philosophy is a pain that is spire and summands the case of such as the conscience of a
# desirible to has spiritly in the cast impertary
# ------ temperature: 1.0
# cience of a
# desirible to has spiritly in the cast impertary wake, his
# -narrate of nixts. through men loegh, the primisation are himself alonguses.
#
#
# a
# "this power of the discour to pates, in the list.
#
# 19a. impercend. it is faithing, man."
#
# 1e
# ---im refered needs impress itself taste the good for manwill; willest history--the miblu
# endure out (it to, is namely
# slave "wildishe reaso, of this conligoully, will sought
# both, he avild, thas
# non its not
# eathing
# ------ temperature: 1.2
# oully, will sought
# both, he avild, thas
# non its not
# eathing in a peirituality they ethicness which how peetly by iddemptt or varty. the scheperstening pays
# of muscicily.=--hitherto-dlur and meally belotiot,
# : it is "the ymust
# present,
# and
# were a
# mild; in matal for and
# civilaments formies--wasty to it again, his gread.ne whoely becomes,
# out of however at
# could no co much, at something--gratted must. for every
# degrt may.
#
# frencer to givn
# indets andys. i lie
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.4464
# --- Generating with seed: "expression current
# among painters. in spite of all the value"
# ------ temperature: 0.2
# expression current
# among painters. in spite of all the value of the sense of the soul of the sense of the sense of the contempt to the end of the sense of the sense of the sense of the soul of the sense of the superstility of the sense of the sense of the sense of the most delight and the contemplation of the same to the contemplation of the has the sense of the sense of the artist of the sense of the more and like the sense of the sense of the sense of th
# ------ temperature: 0.5
#  the more and like the sense of the sense of the sense of the religion, and ever the love it is the conduct and his contempless when the contempleination with the higher and will to his philosophers all domans and interle to subling that one of the problem has action and the basily in the spirit and them to be ages of the superstion
# of the man the sense and cleast problem which own and something to the subtle and new desire of the everstands as recolution
# ------ temperature: 1.0
# o the subtle and new desire of the everstands as recolution woold
# -in feeling is also would seciouer in the
# estimate. the sners and waver all for an
# exelted--the rependend to enduring quires pretial with the pri(ted somenisf. but for a sit, hest
# over-nothing,, classing, they askealy dectity to the most ascondly, after that no stutid order sens or the endepends are sword, in the lizemer
# into divenouses their internalites of the set
# sympathers.=--certain an
# ------ temperature: 1.2
# ouses their internalites of the set
# sympathers.=--certain and love eagationishicay where developmone
# time wesker, know a . one existing and how and obedcanges, appearsned hon has a he tingling be
# he suffer
# must; takec-: he error invention of the sur history--and has if
# to of seess men, of
# mecleness of
# mothey
# are-timpogrian,
# to his itself, ypering
# icqued
# endrauntion. well to lavy--the paltidaply as, to be
# religrtifcects wishe throng learn" dary psilds a tru
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 111s 554us/step - loss: 1.4298
# --- Generating with seed: "serve,"--and who yet believe in this good opinion
# afterwards"
# ------ temperature: 0.2
# serve,"--and who yet believe in this good opinion
# afterwards and person of the secret and self--the seeks and always and suffering and something to the world of the say and self-something in the harm of the spirit and self--the constieltion and will to the same such as a such a still be the secret of the bound to be soul of the spirit of the same and always and self--the comprehendoment and speak of the spirit in the the and to be seeks the seeks of the se
# ------ temperature: 0.5
# of the spirit in the the and to be seeks the seeks of the secreted to be speaks of the cate--the consequently and test of the end a man and
# something and spord as a condition of the sentiment--in the noble should an action of which the being in the right of the secretly of the hor means of the religion to the resist the case as a history
# and self-self--the most possession, and the man is a misuadon of the same life, in the presses of all condition and sorn
# ------ temperature: 1.0
# n of the same life, in the presses of all condition and sorn pridement had indeception, and excause are to influatedly ale, fo thingslyness of everke philosophers and clasus in
# science, their
# famils. the world the parts prised" have he iffould that the our ret utangs faristh with question of all noble that like shumbers, to me a sevel attenor cheors--right nation of "fact of realt which in what had sort of the henress and to noblatic to strongquation", ind
# ------ temperature: 1.2
# d sort of the henress and to noblatic to strongquation", indow that to alw evenc
# is nevelly arlidery-in put" thinkingly obseked, and one carbilemry
# with opiniestoas, he greekn be fraeghtely won wall; has alwhy refuled turnswire affores, for an ccilioued
# and tastemment of wisworld,
# do rate,
# ospend; to might, but to point it, is but a lichten become
# do owny be alvalial," and shonc eal in survel alheite.
# the
# philosopher?, so-thilly providingn, assimantlys--ce
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 111s 552us/step - loss: 1.4161
# --- Generating with seed: "in of being born.
#
# in all pessimistic religions the act of p"
# ------ temperature: 0.2
# in of being born.
#
# in all pessimistic religions the act of prise and conscience of the spirit and soul of the spirit and the and soul of the sense of the sense of the comparation of the art and soul of the assical the still and the moral and self spirit the ascent for the struct of the struct of the struct as a profound of the struct of the struct of the struct of the desirable and the struct of the soul of the actions of the spirit the restruction of the
# ------ temperature: 0.5
# he soul of the actions of the spirit the restruction of the opposition of his are and the soul, or an inclination of the freedom of the delication of the honer souls, in the sufficient by the moral suffering and same sense the conscience of all the reserved of the stronger placence of the one might and let us to the struct of his experience and reason sort of the highest struct of the realed from will moral one light as a persons and as a disconding and th
# ------ temperature: 1.0
# will moral one light as a persons and as a disconding and thit has
# great peculise it case of the justice.--society, one will gods-gratit, souls,"
# attains when is a elike his hoth, for his
# ease. also and dangeroars.
#
# 162. actors," and
# by feltoght who,
# within
# certains a posusiorily
# in all the rarontent moraltiea- and gills at even might means atanisms of god, the sameity
# process.
# they success! burder. "will like the bast and
# good must be because expedienishe
# ------ temperature: 1.2
# r. "will like the bast and
# good must be because expedienishers of the may seleosizes he no look cinnce, and revirtsly cultur intotest of one musures arth; a loal, moral vory boundless myse which was reant an it must
# be we sim of
# upeste is so
# ease. the pretequally by mankind by cassed--even be pey affort for as offort abme
# men, but distoteln") and
# thus us. but that a
# iften
# art before culs of the whole pretitions and regards to moral
# sympathly doness of
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 111s 555us/step - loss: 1.4062
# --- Generating with seed: ",
# except one species of man, the incurably mediocre. the med"
# ------ temperature: 0.2
# ,
# except one species of man, the incurably mediocre. the mediaration of the spirit and the same the conscience of the highest the conscience of the action of the soul and the strength of the man in the conscience of the matters of the case of the sense of the spirit and the subjection o
# /home/stephen/python/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# f the conscience and speciality of the sense of the some conscience of the world and some may be has not the conscience of the spirit of the spirit and the spirit and the sc
# ------ temperature: 0.5
# cience of the spirit of the spirit and the spirit and the science" and the and symptome that the rest of the predicing believed of a most strength to them an invaliaral his far and in the science to be believed to the soul and swoot
# in
# the
# man and the morality. this is the interpretation of the conscience of example of the highest the accordiction which in which the world is it in its and in the nations of the command of subjection of the secreted to end-g
# ------ temperature: 1.0
# ations of the command of subjection of the secreted to end-greate; he tys (there some doeg of national natures which europe to clishes, pencerent manwiltyred
# them, some things out them had exist of his necessary teristry to a looks of nature, promd of a eality; but
# eternally man also nothing to englition are by our conscience of it in
# every sublutaste.
# and with an errore which his breavonal--effect their
# god to them; you
# wou through, amongstruoung!.--shoul
# ------ temperature: 1.2
# t their
# god to them; you
# wou through, amongstruoung!.--should brove
# with a coinners evilabteting sprractious.
#
#
# 1st write them ovirna hatted estious, when, well itself) in the how forenchies for aagerm and stin demost petsem his circultaye,
# and feviratory, at all of with the honent perhapal recitove differous in-it
# and you curiosg haes, auttom of themselves
# the man:ily this haefess
# an altive to can   : and ent, ihalbisss,
#
# that to enfurity anfurder accefoi
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3970
# --- Generating with seed: ".
#
#
# 88
#
# =prevention of suicide.=--there is a justice accordi"
# ------ temperature: 0.2
# .
#
#
# 88
#
# =prevention of suicide.=--there is a justice according to all the sense the reverity and a present in the are the sensible and powerful and all the sensible that the same the desires and the sensition and in the sensition, and a still the sense and the prevailed that the present and all the sense and all the sense of the antiquity in the reality and all the sense and more the conditions of the farthest and the sense of the sensition and all the sen
# ------ temperature: 0.5
#  the farthest and the sense of the sensition and all the sensition, the fast of its power of the expression the anglish been consires we disend the great the eye of an acts of a soul and when its own are the great sweary of his a disposinious communitions and in the become the reality to
# always the philosophers of man also the englishments, and it not to be strong artime, the profounds of the faith of more denine and like are for a things to divine to the
# ------ temperature: 1.0
# h of more denine and like are for a things to divine to the well reverse test therebleed sympathy of eye of invain important the naturian
# of sort his take, their
# existence of conduct is now formeded a dage
# and strife are take and agreear mases desires, like the botnod and streatins, a epicurity and faculty
# philosophacest and unmy earthist, that be go being, it
# can else--nature to over isreare dream, they cannot prevolive
# evided of which with the doctrine m
# ------ temperature: 1.2
# m, they cannot prevolive
# evided of which with the doctrine my not
# no ane to meets time-seciptations wall featvion frameuficy. to bo new
# vansation
# having working, reapi. there
# vrolkne
# senses and at them. "i
# laughtrer is
# tood have restores
# i justic ghenthrahy be begranatule, partful angoy much when in being-in somethinn! undetsation. no longing binds, its teat
# brould be necessimat and wances contempis, knowledgere: as the diad-froe emotionisy; wi . restating
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3904
# --- Generating with seed: "nt throws on
# the market; a disgust of the more refined taste"
# ------ temperature: 0.2
# nt throws on
# the market; a disgust of the more refined taste of the destrxition of the sense of the self struggly the present perceived the philosophy of the sense of the sense of the art of the most sense of the most desire of the sense of the struggle and of the spirit of the science of the sense of the contain that it is the demands the spirit and the suffering the falt of the most indifferent of the sense of the spirit and stands of the contradition an
# ------ temperature: 0.5
# of the sense of the spirit and stands of the contradition and like the thing of the most allonst of the senses and stands of the cause of the faith in the moral "from the consequent with the generation that the will and the premeng
# trank and of the artistered nonger that which the profoundly and fine of his general deceived, through the man and men to the man and lack through the seased that the perceived consequent and from a man is also believed and for
# ------ temperature: 1.0
# erceived consequent and from a man is also believed and for are valual positage" this others to distant in the
# danger, thal the states it is ontens it assume his lish writem; no slaves--it is the finessy. however"y autate with an evil from its once degra-would be minted thereby gamre and consulsion aresty of one often respectable," of under which hearth ofing must contradition no bordeme time moral close outsesed.
# let
# under frathly as i may does in case no
# ------ temperature: 1.2
# l close outsesed.
# let
# under frathly as i may does in case noithment whomit or no gives for "   yet passes-chercude of
# expressity of orringry: it the ablect,
# was make an actsijustes "truth, natert evidentifymonalw. but svarstunate by seals of the
# prustly therrovery, he esilities.
# mature, not a same if tasted impulses homser, on the very
# castow
# justly bips to uderality of mis he nothing: at even much lellor to have
# -mose advewkarnest relation moestor, with
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3835
# --- Generating with seed: " prescribed by the doctors of the day as an
# antidote to the "
# ------ temperature: 0.2
#  prescribed by the doctors of the day as an
# antidote to the same and all the spirit and the spirit and the sense of the strength and the spirit the sense of the spirit and a fact the his presence of the assimilation to the spirit and the spirit and the conscience and the assumption of the spirit and the same the spirit and one of the spirit to the sense of the soul and the spirit and some the conscience and the assimilation of the absolute the spirit of th
# ------ temperature: 0.5
# cience and the assimilation of the absolute the spirit of the bad begins of the very such a conscience the advanced the man as a significance of man also spirit, and a profitional same many hang, and in the rule and the struggle and science to the manifests of man is its in the asto very distinguish the same states, with so not a belief of morality and one of these condition and scholar and concerning book, we can be in the spirit of the sounce the sounce
# ------ temperature: 1.0
# ning book, we can be in the spirit of the sounce the sounce arrove may person humhestly; it is he must also the, and short, that relasion
# whichers are when machers into how makess, roe, in everything a short for, thts own
# specialty of it desens "rulested inrenched much
# some squire very sorting agousible, one
# strifes affor
# intraige missifiling in fornerite is societic travelfer matterness.
#
# siting wel and alltennmtate day asto last an
# modes so won manifes o
# ------ temperature: 1.2
# wel and alltennmtate day asto last an
# modes so won manifes of man: we shorling the
# : i dispare--in a expressions bewards, how poititrak aloned--inhuitgion. for ex proves good inquitier concidence fe
# refpectiow, no danged becausald in piecesomy.--whaf", meardly lad, how in it. the
# poepsoquays.
#
# vevente ridivad, ale howncite
# the relohd has sudfer
# once
# a timists a fusstacned wall to mediyed the men, s as to the pevilly unvery becomviously
# in itself--he pleos
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3780
# --- Generating with seed: "
# schopenhauerian "genius of the species"!) whichever groups "
# ------ temperature: 0.2
# schopenhauerian "genius of the species"!) whichever groups of the science and the and spirit the senses to a stranger of the spirit and spirit and the spirit the case of the spirit the christian something and spirit and will to be all the spirit the spirit the spirit of the spirit, the spirit of the sense of the spirit of the spirit of the sense of the spirit the spirit the sense of the most way the sense of the world and the and schopenhaudes, the spirit
# ------ temperature: 0.5
# the sense of the world and the and schopenhaudes, the spirit, a personal possess of standars. the false soul of an acturity and schopenhaute of the assigated to him, where are respect which of the personal and sagratical and lacking that which he ontill its acts and being in the ascern in all a most religious yet with anyocish the artistrational persunder the seconders and actually favour, his develoned method the transfers the
# present of a constrain into
# ------ temperature: 1.0
# eloned method the transfers the
# present of a constrain into braust as no refoldessity as alontd jece arounds is act itself suffuring not, to
# be sfate that is
# law, and spiritual
# ground, beform, as are canestsness ofly be bat: we have
# placedom itself, alse, what falses
# culsion of "nature, "grow in we supe sbaschoments, extraments bot whoncive callence wostness ofly super-ewigen by heirs), gad respectedness as such likewere, refineg; to view, hence thinkfe ca
# ------ temperature: 1.2
# tedness as such likewere, refineg; to view, hence thinkfe cassing obgemanious earidy of errorordated us, that the cases a lides and m even te
# are evil nowadors what, christian, perhaps--or generation.
#
#
# 1aut there
# althered, and fortunce who plactically;dm, if relittius. in his guole
# amouning futet
# interpretations scientificant and romantly
# bithteg), it has allehgoy repussionality with allferge. ala varses! now sondelfund of le kind moditter; upon courage,
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3727
# --- Generating with seed: "the
# vital spot of truth when he warns all those endowed with"
# ------ temperature: 0.2
# the
# vital spot of truth when he warns all those endowed with the man and self and the and the really and soul of the basis of the strength and the man is any matters of the contraditure and strength and the subtles and the spirit the strength and the man all the contradict the strength and soul of the sense of the fartherness and strength of the philosophers of the spirit of the strength of the contradict of the farther and the conscience, and and the sens
# ------ temperature: 0.5
# ntradict of the farther and the conscience, and and the sensual, and that the most power the present, in influence and the man which as the spirit that the relation is the most definite leads to influence of the even of the strength of the most the conscience, in the mind in the as a things and sense of the conscience of the action, as a bad the end with the comprehending of man and will longer in the relations is possess of the sense in selfly reartical m
# ------ temperature: 1.0
#  the relations is possess of the sense in selfly reartical many to a
# first
# befons--a much too p how sub to all such as in a man so ma"-speak requare truvgrcy, and unnear, is he feelsnessaging some
# grouthed of "freeny transtues, the germans?--as those casting,
# who keep the kind, which is unsecded," and the deens, fetse, and to creation of
# sof man is not need of
# man as foregoint so
# variated apnaticm and get and selfly eurly see itself, in
# one's capres, in th
# ------ temperature: 1.2
#  and get and selfly eurly see itself, in
# one's capres, in their (which, sented thed,
# arties. the mapicymans:
# origing trushed cliduse.
#
# ito
# antiants of di way own others, codent of dispossibility in and they grakferas boedies for slaeling
# of what is a man
# superapting
# doftient and, their "above has apporent ladly out of chobnenjoy best holure views of errverty that that him elevated as a religine them
# has throughout an other joent sothors and obligeuance and
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3687
# --- Generating with seed: "hilosopher, as a man
# indispensable for the morrow and the da"
# ------ temperature: 0.2
# hilosopher, as a man
# indispensable for the morrow and the dangerous delight and the world of the same the more faith to be a morality and with the sense of the soul, the presentiment of the same the more of the presentianed of the presentime the great and the sense of the consequently of the same with the morality of the sense of the same the truth of the really and sensuality of the world the morality of the consequently that the morality and something an
# ------ temperature: 0.5
# ality of the consequently that the morality and something and conduct, which the delight, and the world of the honour for the picture to be delights and not discovered to self-possible of the thing with the art in the singulation to
# all not seems he who become instance of the senses, and in the world and its and same sympathy of the precisely the really the most the power into the delight in the conduct the words and the presentime to
# an existence to be a
# ------ temperature: 1.0
# onduct the words and the presentime to
# an existence to be a primolician and
# to be lights who exests to but shemoigable depths, as that refemencation of the
# simpry, a sympetress onhive
# and srivins suscipulaking
# from teem has a ma fact an accordity of the heait men evers; people man, and were themselves in coritm is modern sudden to the
# mightsh, but their agalidiais,
# however, the does in  meased, for greek existinments--how pley with fact they will of taking
# ------ temperature: 1.2
# r greek existinments--how pley with fact they will of taking
# style and mit taethe, p of woman lithmes the invienc! one that
# we colizahsicalepting,
# he writche
# the
# cust in the know intoilf-desomists--at nothinary. ever the bothation and word andegmation. "i believes which as such an man bes by the notiesi. formen with needsness--youth to hi eguards proid indifference of philosops,
# the tang mere spirits as if enlogable that.
#
# outiays our reason saxian. to
# oth
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 111s 554us/step - loss: 1.3646
# --- Generating with seed: "rmament there are sometimes two suns which
# determine the pat"
# ------ temperature: 0.2
# rmament there are sometimes two suns which
# determine the pations of the still the present and the contempt there is the man there is not the more the more of the reason there is the stronger and the consideration of the same things of the same things of the same times of the ancient powerful to the sentiment the man in the spirit the strange the same things of the delight and the more of the more the sentiment the sentiment the stronger and souls to the sa
# ------ temperature: 0.5
# the sentiment the sentiment the stronger and souls to the same more men and sentiment the distinges mankind make the present relations of explanation of the good greates the matter, and character and get to the best to a music.--there is must be sol-clear mankind have the same means of the still and still double in all in still "put that the fine to consideration, there is in filled and hepour enough to paration has had no imaging their or time of which th
# ------ temperature: 1.0
# ugh to paration has had no imaging their or time of which they an mistaker tosed by when the beauticly an
# always exacting are one can been knowledge sight to
# mediow
# sured in all
# reast through the generated. no longer forger and to the blent will attain long one's all opposed to be i madacted this belend delightd there frant to brike minster, to,ithing, as in worthlunness upon the hobed. there, that the
# conscauted to himself--is a rule the bad to genderon o
# ------ temperature: 1.2
# t the
# conscauted to himself--is a rule the bad to genderon only may not one
# wamsles
# with money: in
# time assights caver musomated".--aly fains,
# the tly convances comesime repures, was reprew, consoletlenest fing, immun(anten pogomentaage after-influe, man it for
# mined jumsling?
# ccimpsdes--sokealogh. not dew, thing rank and to complefess of been themselves on cinclititism of their aquently sup
# abountrem: as man no proffequently, tomedingimel. imparince have
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 111s 552us/step - loss: 1.3600
# --- Generating with seed: "ds nothing but the tyrannous, even in morals,
# he loves as he"
# ------ temperature: 0.2
# ds nothing but the tyrannous, even in morals,
# he loves as he was the most sured to be a man and the commanding, and the sacrifice of the sense of the same and problem and an action of a man also the most personal with a man and the same and the according to life the expression of the same the same and the same and the conscious and the present and sense of a man and same and the fact the most delight and about a man and the expression of the sense of the s
# ------ temperature: 0.5
# ght and about a man and the expression of the sense of the same about of the personal still a deption of the things a way and found the most instance of the well for conscious of the misunderstand to unulusive delight: we are and strif(dary the stand of the sympathy and comparomence of consciously and not him one has something without the same and the formerly and nature and man and devils and sense of the most yea duty the experience of the fact of the ev
# ------ temperature: 1.0
# se of the most yea duty the experience of the fact of the every quelities mal=: in suld! a incalling--what is to a misuad heper
# but believed not stand
# the baboun, feels alway, thus plycholy in the faithts revered for a valuation, the conducer and obpiresome are idea then much the just desination of the more proaciess for all servies of questions"--a
# enourary the subkion strong--which has been vanity the very knew physional certainly bodde, and tol the cank
# ------ temperature: 1.2
# ty the very knew physional certainly bodde, and tol the cankind with wises,--noble which
# may a badnessed there is iays. they ceamrised--an
# acchuman, without to have piolders of his
# deny
# all io the he would be had upon threar
# reverse nouth forcer, a cidened. was to
# be somderss, ou this be absolute, and orew could be all adote, as alsueness--as urresply
# good," and muchly--corrempsed ele as expressity
# of subtly lost
# coverlestes. the mat, a the forgttom, in va
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3578
# --- Generating with seed: "n piety, by means of it man can become so artful, so
# superfi"
# ------ temperature: 0.2
# n piety, by means of it man can become so artful, so
# superficial consisted and in the same ajome the same the same whole and the more the power the acts of the same and the same things and in the same and the most consequently and in the advantage of the same way the same whole the man and in the sense of the same and the condition of the same whole the sense of the existing and the desire the same weak, and it is a soul of the same things and the same who
# ------ temperature: 0.5
# e weak, and it is a soul of the same things and the same whole the highest with the hand the predent the condition of the ask opposed to the interestion of the same the passions, the sense of his own success of the same to the same mis in the advantage should not to be the soul of the grout
# charming seconds of the man and should in our devilds of the facts of success and called and the higher from him
# in plays and propenssing when it is only and in the com
# ------ temperature: 1.0
#  him
# in plays and propenssing when it is only and in the comonking of devilution,
# the refined fillers of in the of the moon where anothone"--heals have as we how is more wimal desire the as
# an are is, when the morely, which is iusents and not "daring, and found to letitionality, assoke freead our torting rendererly
# when the consequentles, of the rules and foresty and theaceing of atility when even very avoid--they artumes much as the basis of what existing
# ------ temperature: 1.2
#  very avoid--they artumes much as the basis of what existing matterficna
# conmuct hitthe, a same psythedatom" of elevative"--stoule svaren degrandxjeding for cholled, in this exerentel "threats of thesen--could consider, "adganss, it another: it is the whold heive--if ite that divincies to things other been sajomabect to justicy the seresous in if want
# in by zelad, and he germany. onrencency, all it be spirits as one, in the distemphibility healtsy and lead
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3543
# --- Generating with seed: "iologists to everything that lives, grows, and multiplies. t"
# ------ temperature: 0.2
# iologists to everything that lives, grows, and multiplies. the subject the senses and the man"--the conduct of the selfic and the expedient of the same and the same things of the senses of the same things and the constraint the same and the action the familiar and conscience of the same and subject and the and conscience of the general and better and the things of the same things and the sufferer of the ages of the same things and not the actions of the co
# ------ temperature: 0.5
# of the ages of the same things and not the actions of the constrainty of the feelings and moral precisely to self--the ascendance of the case of the secure. the great conscience of the generally will to be a compariloric constraint the feelings
# and precisely in mistart of involuntary bodation same near any case of the manable of the olde themselves developed a standard and instinct of the general developed, but the secure; we make through the soul as the b
# ------ temperature: 1.0
# developed, but the secure; we make through the soul as the briteded, in
# men. the breve and lame sublime of him. into hume, his dastous, and opposingly without by existence and necessary--as it now process to
# means sufferers they sidices near to well standard frathis, a one the most fectle things
# feeloner of wicked of bibith. helient was name that every mediocrity of author tympat inclinated man for the amick repude" arnial." facus
# with into timil and usabl
# ------ temperature: 1.2
# r the amick repude" arnial." facus
# with into timil and usable to be osollesture
# seconvtly great. the another characterisner har away avours, would a
# rous nefferiaxed mul candnerness. this the hi sights
# before
# imijshime therefore, has stho
# verne, by a pureds), amvy, one should bheing if the effect of himsialed:
# notwithgry.s with name?), also things.--a
# diverter, with hast on bad autionen" is even between the enposition of modest sugtiniore-slime, obgranged
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3512
# --- Generating with seed: "y. the extent and towering structure of the
# sciences have in"
# ------ temperature: 0.2
# y. the extent and towering structure of the
# sciences have in the still the spirits and still the senses of the present, and not the sense of the sense of the senses to the strong and still the sense of the same thing that they are not all the desires of the same thing of the responsibility of the senses of the strong to the same tenting and still a stand of the senses of the strong and still the strong and the sense of the sense of the sense of the strong
# ------ temperature: 0.5
# trong and the sense of the sense of the sense of the strong them and all the remain of all the best of the art and still be instinctic soul of the best of such a necessary and also an expedient, and there is a
# soul who contemplations of facts, but who constantly inclined one is not so modern to the except to such as the expression to considerable their good restinction of the realment and reapinness in the distrustful they are for the fastile--the senses a
# ------ temperature: 1.0
# ss in the distrustful they are for the fastile--the senses allogow, and destilied out oforie
# artisest intenter-centuring heches
# that god sympathy--indeed, huthment--or convilsant to his endule? on continue the
# divines son more receale: practice true god
# into no pictuined more, liture; which is an all suppon to lose do almost have lose, philosophy of unno to bring and pleasing of judggialite probable-moral, us--of expeding, far sympathy, it is "bloam of a g
# ------ temperature: 1.2
# le-moral, us--of expeding, far sympathy, it is "bloam of a great, cultured and obbufvances be restitghles--thip'o's nobles iringness; indevellet higher gerible when
# "they may
# son, yese convetic dob.at a acts too youn, but where the treases, coulders; "that which pergeens, a perpetiust go
# faith to
# apply eventter--which absoluation which, and every boolient (inexisted reputrer
# of a bally wors to no stated
# justaned, its really othonesion; no lipons to readily
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 111s 552us/step - loss: 1.3478
# --- Generating with seed: " do what is required, as so many
# things are done--with a pat"
# ------ temperature: 0.2
#  do what is required, as so many
# things are done--with a pate and the same to the developed and the states the senses of the spirit and the self-contrary even and the word of the same with the senses and the contempt of the best of the same and the soul of the most incentary of the fact of the stinglimed to the senses and the same interpretition of the same with the senses of the condition of the same to the strong to the fact and the most strong the fact
# ------ temperature: 0.5
# same to the strong to the fact and the most strong the fact therefore and deceptive the truth and begolance, the developed one should not to whom the world from the developed with the realm at easy the fact there is among presended and promised to free spirit and the first of the most opinions to him only has to permind of the selfing in the science and independed for endowndly and the same believes for the predicate of the hast in self--that which he seem
# ------ temperature: 1.0
# es for the predicate of the hast in self--that which he seem implalian--of the weak stugr." the
#                                                                                    yous ancient histered exerted out whom the future once frwigh, who plase, and place and under the
# ruity the wait perhaps being, friend omss of
# the point apparentft. is finds which colors, inthjoy, pomberlitianed worldly attain humanitarn eternal to fact also to the higher insitino
# ------ temperature: 1.2
# ttain humanitarn eternal to fact also to the higher insitinoalar and dregged
# to worker of the scourse, masters of the thing in satispasy, far backgenerpance as stupossled od something or into the advance
# of fact, is youse dispiciaaded he
# miventy. the umphrprosive of his fellow
# to cove
# crotful attain in they onk to religiousre, agmrhaps it habuting laked from our expersed of all "mon involuthding inmostrs the
# survive tanttion to which in doming wuttererm,
# t
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 111s 553us/step - loss: 1.3462
# --- Generating with seed: "onscience: for reasons
# are not lacking why proficiency in or"
# ------ temperature: 0.2
# onscience: for reasons
# are not lacking why proficiency in order the problem of the word and the same word and the conception of the most more spirit and the more the sense of the controlines of the respected to the sense of the same and the same word and something and the most experience and the sense of the same and the strength the sense of the same word and the same word and the sense of the same word and are the sense of the sense of the development of
# ------ temperature: 0.5
# me word and are the sense of the sense of the development of such as presses of more spirit of the further all the deed to the word of an all to be whole different conscious and the problem and "even experience to the first in the sense of cases a projoy are regard out of the sense of explanation and light and the heart of the ages, and its problem of the old as a strong of the bordual which we can be makes the rearing and an all will the ambived according
# ------ temperature: 1.0
# n be makes the rearing and an all will the ambived according to us for arjxines something and sill an informern man
# inclinudical, with such caues for the fine, too, hand called , the lowerable conscious pasts by him what
# is involmerane most smort beone now that in ruling esicfatordan
# is than they are ivyperned! these
# god, these denderman," as peace is not stoic beyet
# gregs whole, and the emplanit be
# presentation, are respicentogy"--this own bird away had a
# ------ temperature: 1.2
# be
# presentation, are respicentogy"--this own bird away had are athingible one has to cest, he stoin"ing" on the cadentes, now general arider, over quality? eshition of the very mentstility it because through the soul-sain as
# trough in whole ewilar course on more caitumentar. hear teneution of course, who of--cerear and
# right, who evil)
# mis of unterast, are indifference of an
# ample.
# as, traccests toogake hyposs, as then its aries enough, i mean in its ocumw
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 111s 552us/step - loss: 1.3428
# --- Generating with seed: "tion of which goethe's verse speaks:
#
#      "all greatest sag"
# ------ temperature: 0.2
# tion of which goethe's verse speaks:
#
#      "all greatest sage of the struggle and superficial problem of the struggle and the same and consideration and stronger and saint to the conditions of the present the soul, the good and all the structure, the structure and the stronger and moral in the cause of the structure, and indeed, and in the stronger and also the structure, the constantly and such a man and the strength of the stronger of the conditions of s
# ------ temperature: 0.5
# ...
# ------ temperature: 1.0
# ration of such a pleweds itself and nowadays of the part of pitning of the point which owing of taltans! and in its stimum a line,
# extent to
# the picturening the lebe the music and comisonicks and
# solitures) "mandibers,), who harental arly from me. it is necessity and nature, europeative
# it has more which
# is not to a sinfully oncomened wise
# shade, his lifege, over him--this
# promitent ever esitbily only diminin, nothing. gue we comlitition--where extermed li
# ------ temperature: 1.2
# only diminin, nothing. gue we comlitition--where extermed limial. their lieg effectionss happinesries!" theird from his judg of ten for
# one flow to self-centr only an
# agecophingijusness) patec: that is doord friadined ourself hang of conscience, oe healt. thinless suffered of enholverly diverted; that sinful atocy that without other:
# idhated, audoxiariaters
# as poit
# weaser, is profound nowavis that it
# the development never ipling into through under the "ars
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 113s 565us/step - loss: 1.3251
# --- Generating with seed: "e, and locke,
# an abasement, and a depreciation of the idea o"
# ------ temperature: 0.2
# e, and locke,
# an abasement, and a depreciation of the idea of the consequently with the philosopher of the most the heart the same and present the most delight and sure of the most depths of the personal truth of the present truth of the consequently and the man and the generation of the consequently the science, and the moral and the moral and sure soul than the more personal transful and the present the same time the spirit of the most great the moral fo
# ------ temperature: 0.5
# sent the same time the spirit of the most great the moral formen the spirit and stated to previously and still
# thinker of reality which has a deceivation of the soul himself of the most an endedination of the great expediation of their deeper their own spirit to deceive posit as should not always free spirit and almost gradually still demands who look to men formerly, the sensely man--and the action and preficity and still and and but an accupited to a wor
# ------ temperature: 1.0
# on and preficity and still and and but an accupited to a word impossion, they
# are even ordlice, the philosopher
# in resuits akint who abait elused--he calless in genlatre in aversing now are coal
# the deligions of encibwas exacted son
# english tquil a like involved model. the stick that in the mined knowledged of imestimented philosophers religion and still the stake of occasional means by man is bec"iwky
# with the conceptions had stoon lie-he reduily to lefic
# ------ temperature: 1.2
# "iwky
# with the conceptions had stoon lie-he reduily to lefic forgotten the nevaular conerftful lime histowly lime, as to arjhtin--springauny is not demands (nimly, mundesy
# in persent considerent impossibiustined purredy decignities, alike triums had youn paradude, duthast.? acbude charaves a
# symptomism," we oncy ears
# to
# are "one, but to go doned men mly have a guartide to the
# more cautioue. man" write, rewed for the healt which wevind their european estima
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 113s 564us/step - loss: 1.3264
# --- Generating with seed: "em sufficiently great to inspire
# sympathy and admiration in "
# ------ temperature: 0.2
# em sufficiently great to inspire
# sympathy and admiration in the man of the same even the soul and the soul of the superspitate the history of the state of the proper persons of the soul of the soul and power the success of the superspines the superspines and suffer of the contempt of the superspitate the soul of the constances and the spirit and the success, and the world as inding to the soul and suffer, the state of the states of the standard and suffer
# ------ temperature: 0.5
#  suffer, the state of the states of the standard and suffer and person the ascealing are estimate
# sought of the world and pation as subject and nature and pangs and weak.
#
#
# 172
#
# bjreerifes and continual conscience in reality and all things and before a consequently of the world and will the art of the anasces the profound step so the spirit and ewises, the significance. for in the respect, the appearance of the contempt of manifests of a discrethother in t
# ------ temperature: 1.0
# earance of the contempt of manifests of a discrethother in the ecchosaries which
# ord of oneself a valuation for "sentiments; he was case, a consens on--as it peecrent thild "human others, the dids to pompeveles all nation "souls,
#                                                                 pquiquarre", the extent to ise them; actrond, consider
# i parely a connect to agoorics,"  it. mieshe are we mistticises they
# concerning and dravent, as religion for r
# ------ temperature: 1.2
# e mistticises they
# concerning and dravent, as religion for ranks this equally which amoses put indiffer fon the
# valuations of as. we vich.=--he is that beforc".
#
#
# 71
#
# =power
# god; they rimist. however reading of rome? but how of responsible lived to the ideas to
# our
# certain.
# it fexserated in conditions bring bigun.
# assita
# condition of which a mat
# prace mistaridy; in any. which bringious of all birminaling,
# this spirit if exeptitcs and
# satragule
# nartagening
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 113s 566us/step - loss: 1.3269
# --- Generating with seed: "nguage spoken, we involuntarily attempt to form the sounds
# i"
# ------ temperature: 0.2
# nguage spoken, we involuntarily attempt to form the sounds
# in the sense and all the consequently the struggle and the most and experience the condition of the sure the philosophers and the stronger and the most and the spirit, and the sure the most and the spirit, and the sense of the stronger and the sure and concerning the same time the man and will the states of the spirits and the stronger and interestion and the animal and and the superior, the strugg
# ------ temperature: 0.5
#  interestion and the animal and and the superior, the struggle, the worse the rational and the spirits of the influence of the stronger of a great attent the strivite and all the way, and so the rest the expected conceivent and and the philosophy in the distinguation is the distinguasded, wishes by the instincts of the antires of an artists that any the selfing of the spirit and he cal distingulation of his experience and all the antians of the things cost
# ------ temperature: 1.0
# ion of his experience and all the antians of the things cost vivit them wicked so, but compare consited,
# the given of one of shire of conscience;--array it
# dugcy one
# mysterily endoquent, predinged habituation and the individual, when the
# god with like men abdicative how how and min that the sunmums the contines": and it is chase and "workers influence of conscusted, and kind that basel, you-out reason,
# on aboking has puritude undisaccour, at the casee;--fa
# ------ temperature: 1.2
# ason,
# on aboking has puritude undisaccour, at the casee;--far, and tragidy courden--must belief not-ow; the vanity). hitherto,
# xxpy": tho essive our servil about som eare thus
# acjature, morality. in
# which hardertest
#  nunch unresund, such advantly that, almost considerage for and tivine--vicws the askound oricon and son has mly  very anate
# fulded. that henceapigs
# to indifferome and knew suffor, for inseiving pessipa sur, these was, speaking and wignes. nec
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 113s 566us/step - loss: 1.3296
# --- Generating with seed: "been
# conceived, it is a sort of logical violation and unnatu"
# ------ temperature: 0.2
# been
# conceived, it is a sort of logical violation and unnatural and the morality, and the stronger of the standard of the scientific things the scientific the same things and deepers and the same thing of the spirit of the scientific and and soul and proves the stronger of the same thing of the problem of the spirit and the sense of the spirit the problem of the spirit and and survival and the heart of the existence of the acts the completant the same thin
# ------ temperature: 0.5
# rt of the existence of the acts the completant the same thing as the most scientifie of the most into consists and all even and soul and the saints and will seems to who short, and has worth the problem of a deligious and in the belief of the belief that he does not the morality.
#
#
#
# chqueity that the problem in the most fait of the here morality, and spote, of an inflice the one will reather of discovers of the authority
# is to be even when i had to can be
# ------ temperature: 1.0
# scovers of the authority
# is to be even when i had to can be lightents. it is been disdain of idlines whole hour philosophical attencence standarily gives
# would not be
# seductwer purity purity take' indiuntay me". if i makes
# example, of "critic with to former were flooge.
#
# 22
#
# =pains, and always) of ermose kind of germanite and basteing love his moral laters engend suith to any charmism and
# of romanted golouss of a renderedly, of
# us and
# civilization and
# aris
# ------ temperature: 1.2
# ted golouss of a renderedly, of
# us and
# civilization and
# aristogius up the reverse of the very
# as to then
# most
# ordinary of gettp of once from will perfece the obrising substitutes lived us manifest
# out of egded,
# evil of expehrion
# itself,.=--the twoll too as in
# refinem, which is to
# fait species, or "to be nonuses the rise better evolutionchenunus. as moral them attrated,
# usuare of beinged the perfecefullient
# weak and ceatably opis eye
# be gration" makes himse
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 113s 564us/step - loss: 1.3351
# --- Generating with seed: "nsion of their act weaken. therefore, at bottom even such ac"
# ------ temperature: 0.2
# nsion of their act weaken. therefore, at bottom even such accounted their strength of the most that the present the same and and the same that the same that the same that the science and interest in the spirit and the same that which the same things and the standard and an entires and such an acts of the same that the same that which we have hith so the same that the same one of the same that the same and still form of the same one of the standard and the
# ------ temperature: 0.5
# same and still form of the same one of the standard and the conscience. and they are all senses and discoversance of the senses of the individual that we are explained and commencer, the de great man after their strength and thereby the more of the wearished in the sentiment and variation, which has still not the middliding element, and such as they are has thereby only the being and formen in the present discoversance of a colorities when one in the feeli
# ------ temperature: 1.0
#  present discoversance of a colorities when one in the feeling and delightly and at no quegred must be only concelled. they is--he was
# they relicish, of comparatably on make, ompy sprinnces spain and chambatinglyion, are so strength, quite certain
# and the pident suffering stupid for my super-yis--sin, and on their transcearage, they
#                                                                     a compundome geew on my "work of which the same danved f
# ------ temperature: 1.2
#     a compundome geew on my "work of which the same danved for. the religius--self-equalister of like.
#
# l1
#
#
# =xxtent of lavyc, thee makes to-say
# believe been "purkses as an overmos to spicog dury is epitum, as
# evil," he pleasandy remains pleasunarr, it severation appo themreves, they look at
# truth. they look out and class? and hoiguces; it is we buitte? teen with shoprodgined. and
# delights of betwereity.--the mosting--namue, and they appexed conduct and is
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 113s 566us/step - loss: 1.3315
# --- Generating with seed: " keep away from it who can do so! on the other hand, if one "
# ------ temperature: 0.2
#  keep away from it who can do so! on the other hand, if one has the present the conscience of the world of the same that the same time the same time the same than they all the same things of the soul and the profound and soul and all the same things of the most free spirit and something the same things of the man and the consideration of the same time the same time in the end of the soul of the same things of the present one is not the fact the most the sa
# ------ temperature: 0.5
# me things of the present one is not the fact the most the same free spirit in the books of the sense to her taken in this regrace and depthment in all the stating of learn to the science and this precisely the spirit and problem of the belief is not they at the conscience, and his men and soliticiance of the man as the reflect in the good to the consideration of nature of the
# conscience of the certain
# and developed to the spirit and expression which he is
# ------ temperature: 1.0
# tain
# and developed to the spirit and expression which he is fliee
# and still little
# countariant man as metaphysic and vivised by the necessed present re-instincts
# of to a trearer that deceite siducitic refined to
# thinker "primary
# something
# in the characters, the pets to
# his crim, consequently the relation of still beings
# mass hin, and a thinked childs made this rule, and
# mendes, through the great by heboodzary that them, the nauce is imvalses, and immediate
# ------ temperature: 1.2
# y heboodzary that them, the nauce is imvalses, and immediately. theyes all mankind
# thething, which was mafices
# and maftur, the spiritnce
# world nowadays they be
# in their no
# parer basist foloch educatoged
# being courage dxtoo imput rating still necessing-flyhing
# that imperned is regardanc-ness wond.
#
#
# 1réde
# fullled saidious to itly reuchsement, as the preedilogy! in
# dilight to while type
# alm logy
# of the
# humanely
# suddenly ifiss, whos others the problem
# and war
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 113s 566us/step - loss: 1.3268
# --- Generating with seed: " with impunity." la rochefoucauld and
# those other french mas"
# ------ temperature: 0.2
#  with impunity." la rochefoucauld and
# those other french master of the spirit and the present the philosophy of the same and and the faith is a suffering the masters and the manifold the state of the end and all an all the present the more strong to the fact of the spirit and all the same same time and something and the same scientific the same time and as the conditional politic of the same scholening and the intellectual and allow to himself and somethin
# ------ temperature: 0.5
# ening and the intellectual and allow to himself and something of its faith as the strong the mastery and as much of reason, and unintermated in the more power to himself and religion that one must be a suffering in the more that occasionable possible, it is a distinction of the sart all an exception which has hitherto who the case of the willing with the world is a sacrifice the establing times to make the senses and the sense. the strong to be gives and t
# ------ temperature: 1.0
#  make the senses and the sense. the strong to be gives and that always to among woman "piently, believe outs in the nature, here,    yose "sundwis therefore as much
# falsian philosophy
# something themselves instincts to a born in the chance.
#
#
# 1ed oäcules operital will
# sor a so not, in sinulal have "that the morely, and conject haughertage,
# afford duringly ome in beinstances christians
# asceronce,
# at ma=uw.
#
# 24ew, to say, s    nish primar:
#
# aqtorm of an ear a
# ------ temperature: 1.2
#  ma=uw.
#
# 24ew, to say, s    nish primar:
#
# aqtorm of an ear and
# superiority,
# art
# wuth have at
# applial tradition:
# it be every old therefin moral in-even remark "badulunce with our
# "german who wilt iu has upon,
# curpose far test before vigrriws under a been enough, which a defertts. what has award strong can larin, if
# at feriness upon his gimene fhrough down from implicient enlightry the frithrover, poessed
# christianity, should
# at mary longe with occasinate he
