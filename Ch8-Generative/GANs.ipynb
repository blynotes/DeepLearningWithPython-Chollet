# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)
discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Adversarial Network
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
        (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = '/home/stephen/Scripts/Books/DeepLearningChollet/Ch8-Generative/'

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
    
    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)
    
    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])
    
    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                            np.zeros((batch_size, 1))])
    
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)
    
    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)
    
    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
    
    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))
    
    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
        start = 0
    
    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')
        
        # Print metrics
        print('discriminator loss:', d_loss)
        print('adversarial loss:', a_loss)
        
        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))
        
        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 21s 0us/step
# /home/stephen/python/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training.py:479: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss: 0.6951221
# adversarial loss: 0.67724144
# discriminator loss: 0.12979773
# adversarial loss: 10.161685
# discriminator loss: 0.6958469
# adversarial loss: 0.89107907
# discriminator loss: 0.6948527
# adversarial loss: 0.7880247
# discriminator loss: 0.68985045
# adversarial loss: 1.0213724
# discriminator loss: 0.694196
# adversarial loss: 0.7510228
# discriminator loss: 0.6967782
# adversarial loss: 0.73539555
# discriminator loss: 0.6850604
# adversarial loss: 0.7749256
# discriminator loss: 0.70180386
# adversarial loss: 0.7418088
# discriminator loss: 0.7050497
# adversarial loss: 0.7661802
# discriminator loss: 0.6929507
# adversarial loss: 0.7324163
# discriminator loss: 0.6801376
# adversarial loss: 0.7547473
# discriminator loss: 0.68879426
# adversarial loss: 0.78795975
# discriminator loss: 0.7138542
# adversarial loss: 0.8156335
# discriminator loss: 0.7121935
# adversarial loss: 0.81135243
# discriminator loss: 0.6970531
# adversarial loss: 0.75075275
# discriminator loss: 0.6849845
# adversarial loss: 0.7482742
# discriminator loss: 0.6862048
# adversarial loss: 0.74672824
# discriminator loss: 0.7000991
# adversarial loss: 0.7186563
# discriminator loss: 0.6914247
# adversarial loss: 0.75652635
# discriminator loss: 0.7034939
# adversarial loss: 0.7026719
# discriminator loss: 0.701855
# adversarial loss: 0.76276433
# discriminator loss: 0.72350967
# adversarial loss: 0.76883715
# discriminator loss: 0.6880106
# adversarial loss: 0.7764938
# discriminator loss: 0.68662596
# adversarial loss: 0.6214857
# discriminator loss: 0.7111137
# adversarial loss: 0.7624254
# discriminator loss: 0.6740799
# adversarial loss: 0.6593845
# discriminator loss: 0.6959208
# adversarial loss: 0.8212434
# discriminator loss: 0.6866735
# adversarial loss: 0.7646354
# discriminator loss: 0.6997037
# adversarial loss: 0.767183
# discriminator loss: 0.69634765
# adversarial loss: 0.675994
# discriminator loss: 0.6993278
# adversarial loss: 0.7428123
# discriminator loss: 0.6821208
# adversarial loss: 0.7704542
# discriminator loss: 0.6938367
# adversarial loss: 0.7611239
# discriminator loss: 0.7144785
# adversarial loss: 0.73162585
# discriminator loss: 0.6935074
# adversarial loss: 0.8200487
# discriminator loss: 0.7111579
# adversarial loss: 0.761164
# discriminator loss: 0.68908864
# adversarial loss: 0.7670351
# discriminator loss: 0.6994885
# adversarial loss: 0.74578065
# discriminator loss: 0.6966487
# adversarial loss: 0.71321404
# discriminator loss: 0.68728757
# adversarial loss: 0.7292975
# discriminator loss: 0.6963941
# adversarial loss: 0.7371626
# discriminator loss: 0.6954589
# adversarial loss: 0.8800538
# discriminator loss: 0.6990172
# adversarial loss: 0.7154635
# discriminator loss: 0.6780639
# adversarial loss: 0.6902161
# discriminator loss: 0.6948778
# adversarial loss: 0.77624416
# discriminator loss: 0.6813321
# adversarial loss: 0.80623597
# discriminator loss: 0.7225925
# adversarial loss: 0.8449031
# discriminator loss: 0.6797606
# adversarial loss: 0.7425686
# discriminator loss: 0.7108065
# adversarial loss: 0.84875154
# discriminator loss: 0.69245815
# adversarial loss: 0.78541327
# discriminator loss: 0.6751013
# adversarial loss: 0.70585626
# discriminator loss: 0.7084173
# adversarial loss: 0.8789609
# discriminator loss: 0.6668733
# adversarial loss: 0.7305323
# discriminator loss: 0.6721398
# adversarial loss: 0.78590566
# discriminator loss: 0.6971904
# adversarial loss: 0.70701253
# discriminator loss: 0.65037644
# adversarial loss: 0.6901623
# discriminator loss: 0.68694484
# adversarial loss: 0.74316835
# discriminator loss: 0.68438834
# adversarial loss: 0.8933425
# discriminator loss: 0.7998326
# adversarial loss: 0.9321135
# discriminator loss: 0.6625385
# adversarial loss: 0.7719178
# discriminator loss: 0.6998414
# adversarial loss: 1.1025665
# discriminator loss: 0.6845724
# adversarial loss: 0.7811092
# discriminator loss: 0.6841656
# adversarial loss: 0.85694635
# discriminator loss: 0.7099302
# adversarial loss: 0.91130817
# discriminator loss: 0.6857816
# adversarial loss: 0.92540264
# discriminator loss: 0.7110632
# adversarial loss: 0.8434733
# discriminator loss: 0.6858716
# adversarial loss: 0.8146864
# discriminator loss: 0.6893517
# adversarial loss: 0.8029116
# discriminator loss: 0.6447317
# adversarial loss: 0.726136
# discriminator loss: 0.6737531
# adversarial loss: 0.782308
# discriminator loss: 0.7954351
# adversarial loss: 0.70007586
# discriminator loss: 0.72276914
# adversarial loss: 1.2402798
# discriminator loss: 0.6829439
# adversarial loss: 0.9167101
# discriminator loss: 0.6686206
# adversarial loss: 0.7651279
# discriminator loss: 0.68899155
# adversarial loss: 0.8579499
# discriminator loss: 0.6591078
# adversarial loss: 0.83685
# discriminator loss: 0.7056961
# adversarial loss: 0.7620667
# discriminator loss: 0.70549047
# adversarial loss: 0.6253341
# discriminator loss: 0.67385256
# adversarial loss: 0.6832179
# discriminator loss: 0.670718
# adversarial loss: 0.7695385
# discriminator loss: 0.66352874
# adversarial loss: 0.76599276
# discriminator loss: 0.6796267
# adversarial loss: 0.90751565
# discriminator loss: 0.63884485
# adversarial loss: 0.8204645
# discriminator loss: 0.660028
# adversarial loss: 0.89943314
# discriminator loss: 0.6448712
# adversarial loss: 0.69662845
# discriminator loss: 0.67563695
# adversarial loss: 0.8797388
# discriminator loss: 0.69946975
# adversarial loss: 0.8231937
# discriminator loss: 0.6543983
# adversarial loss: 1.2266397
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5a0dbbe0fb14> in <module>()
#      23
#      24     # Decode them to fake images
# ---> 25     generated_images = generator.predict(random_latent_vectors)
#      26
#      27     # Combine them with real images
#
# ~/python/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1165                                             batch_size=batch_size,
#    1166                                             verbose=verbose,
# -> 1167                                             steps=steps)
#    1168
#    1169     def train_on_batch(self, x, y,
#
# ~/python/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/python/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/python/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~/python/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:
